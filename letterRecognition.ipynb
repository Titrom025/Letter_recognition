# %%
import os
import re
import random   
import io
import time
from shutil import move

import pdfminer
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams

from pdf2image import convert_from_path
from PIL import Image, ImageDraw, ImageFont

from navec import Navec
from slovnet import NER
from ipymarkup import show_span_ascii_markup as show_markup

import extractors

# %%
RECEIVER_ORGS = {'заслон':'АО «Заслон»'}
RECEIVER_PERSONS = []

# %%
def get_files(dirpath, ext):
  files = [s for s in os.listdir(dirpath)
     if os.path.isfile(os.path.join(dirpath, s)) and os.path.splitext(s)[1] == ext]
  files.sort()
  return files


def createDir(dirpath, ext):
  if os.path.exists(dirpath):
    for file in get_files(dirpath, ext):
      os.remove(os.path.join(dirpath, file))
  else:
    os.mkdir(dirpath)
    
def createDirIfNotExist(dirpath):
  if not os.path.exists(dirpath):
    os.mkdir(dirpath)

# %%
def draw_words(first_line_index, last_line_index, words, text_lines,
        drawn_boxes, xmls_boxes, pageNum, field_type, border_color):
  
    
  if first_line_index == last_line_index:
    
    first_line = text_lines[first_line_index]
    chars = []
    for elem in first_line._objs:
      if isinstance(elem, pdfminer.layout.LTChar):
        chars.append(elem)    
    first_line._objs = chars
    first_line_text = first_line.get_text()

    x_left = first_line_text.index(words[0])
    offset = x_left
    for word in words[:len(words)-1]:
      offset += len(word)

    if len(words) == 1:
      x_right = x_left + len(words[0]) - 1
    else:
      x_right = first_line_text.find(words[len(words) - 1], offset) + len(words[len(words) - 1]) - 1
    
    if x_right == -1:
      return False
    
    return drawElement(
        first_line._objs[x_left].bbox[0] - 2, 
        first_line._objs[x_left].bbox[1] - 3,
        first_line._objs[x_right].bbox[2] + 2,
        first_line._objs[x_right].bbox[3] + 3,
        ' '.join(words),
        drawn_boxes, xmls_boxes, pageNum,
        field_type=field_type, border_color=border_color
    )
  else:
    
    first_line = text_lines[first_line_index]
    chars = []
    for elem in first_line._objs:
      if isinstance(elem, pdfminer.layout.LTChar):
        chars.append(elem)    
    first_line._objs = chars
    first_line_text = first_line.get_text()

    x_left = first_line_text.index(words[0])

    if drawElement(
        first_line._objs[x_left].bbox[0] - 2, 
        first_line._objs[x_left].bbox[1] - 3,
        first_line._objs[len(first_line._objs) - 1].bbox[2] + 2,
        first_line._objs[len(first_line._objs) - 1].bbox[3] + 3,
        ' '.join(words),
        drawn_boxes, xmls_boxes, pageNum,
        field_type=field_type, border_color=border_color):
      
      last_line = text_lines[last_line_index]
      chars = []
      for elem in last_line._objs:
        if isinstance(elem, pdfminer.layout.LTChar):
          chars.append(elem)    
      last_line._objs = chars
      last_line_text = last_line.get_text()

      x_right = last_line_text.index(words[len(words) - 1]) + len(words[len(words) - 1]) - 1

      drawElement(
          last_line._objs[0].bbox[0] - 2, 
          last_line._objs[0].bbox[1] - 3,
          last_line._objs[x_right].bbox[2] + 2,
          last_line._objs[x_right].bbox[3] + 3,
          ' '.join(words),
          drawn_boxes, xmls_boxes, pageNum,
          field_type=field_type, border_color=border_color)
      
      for middle_line_index in range(first_line_index + 1, last_line_index):
        middle_line = text_lines[middle_line_index]
        chars = []
        for elem in middle_line._objs:
          if isinstance(elem, pdfminer.layout.LTChar):
            chars.append(elem)    
        middle_line._objs = chars
        middle_line_text = middle_line.get_text()

        drawElement(
            middle_line._objs[0].bbox[0] - 2, 
            middle_line._objs[0].bbox[1] - 3,
            middle_line._objs[len(middle_line._objs) - 1].bbox[2] + 2,
            middle_line._objs[len(middle_line._objs) - 1].bbox[3] + 3,
            ' '.join(words),
            drawn_boxes, xmls_boxes, pageNum,
            field_type=field_type, border_color=border_color)

      return True
    
    return False

# %%
def highLightWords(words, text_lines, drawn_boxes, xmls_boxes, pageNum,
           field_type=None, border_color="green", after_word=None):
  
  after_word_found = True if after_word is None else False
  
  for first_line_index in range(len(text_lines)):
    
    first_line = text_lines[first_line_index]
    
    chars = []
    for elem in first_line._objs:
      if isinstance(elem, pdfminer.layout.LTChar):
        chars.append(elem)    
        
    first_line._objs = chars
    first_line_text = first_line.get_text()
    
    founded_words = []
    
    if not after_word_found:
      if after_word not in first_line_text:
        continue
      else:
        after_word_found = True

    if words[0] not in first_line_text:
      continue

    added_new_word = True
    line_index = first_line_index
    
    while added_new_word:
      added_new_word = False
      
      if line_index == len(text_lines):
        return False
      
      line = text_lines[line_index]
    
      chars = []
      for elem in line._objs:
        if isinstance(elem, pdfminer.layout.LTChar):
          chars.append(elem)    
          
      line._objs = chars
      line_text = line.get_text()
      
      position = 0
      for word in words[len(founded_words):]:
        if word in line_text:
          position = line_text.find(word, position)
          if position != -1:
            founded_words.append(word)
            added_new_word = True
          else:
            break
        else:
          break
          
      if len(words) == len(founded_words):
        if draw_words(first_line_index, line_index, 
              words, text_lines,
              drawn_boxes, xmls_boxes, pageNum,
              field_type=field_type, border_color=border_color) == True:
          return True
        else:
          break
        
      line_index += 1
  return False

# %%
def drawElement(x0, y0, x1, y1, text_value, drawn_boxes, xmls_boxes, pageNum,
        field_type=None, border_color="green"):

  bbox = (int(DPI_SCALE * x0 - 5), int(DPI_SCALE * y0 - 5) - 10000 * pageNum,
        int(DPI_SCALE * x1 + 5), int(DPI_SCALE * y1 + 5) - 10000 * pageNum)

  if not (bbox, text_value) in drawn_boxes:
    drawn_boxes.append([bbox, text_value])
    if field_type is not None:
      xmls_boxes.append({'field_type': field_type, 'text_value': text_value, 
                 'bbox': bbox, "pageNum": pageNum, "border_color": border_color})
    return True

  return False


def parse_obj(lt_objs, text_lines_to_handle):
  global rawText

  for text_box in lt_objs:
    if isinstance(text_box, pdfminer.layout.LTTextBoxHorizontal):
      for line in sorted(text_box._objs, key=lambda obj: obj.y1, reverse=True):
        text = line.get_text()
        if len(text) > 5:
          text_lines_to_handle.append(line)
          rawText += text[:-1]
          if text[-1:] == "\n":
            rawText += " "  
          else:
            if text[-1:] == " ":
              rawText += " "  
            else:
              rawText += text[-1:] + " "

# %% [markdown]
# # Markup docs

# %%
def highlightObjects(objects, field_type):
  print("\nHighlight", field_type)
  for words in objects:
    # print(' '.join(words))
    highLightWords(words, text_lines, drawnBoxes, xmlsBoxes, pageNum,
     field_type=field_type, border_color=border_colors[field_type])

# %%
def combineSimilarBoxes(objects):
  hasChanges = True
  while hasChanges:
    hasChanges = False
    for first_index, first_obj in enumerate(objects):
      if hasChanges:
        break
        
      for second_obj in objects[first_index:]:
        if abs(first_obj["bbox"][1] - second_obj["bbox"][1]) < 1 \
          and abs(first_obj["bbox"][3] - second_obj["bbox"][3]) < 1:
          
          if first_obj == second_obj or first_obj["field_type"] != second_obj["field_type"]:
            if first_obj["field_type"] == "NUM" and second_obj["field_type"] == "ADDRESS":
              if second_obj["bbox"][0] - 2 < first_obj["bbox"][0] \
                and second_obj["bbox"][2] + 2 > first_obj["bbox"][0]:
              
                objects.remove(first_obj)
                hasChanges = True
                break
                
            elif first_obj["field_type"] == "ADDRESS" and second_obj["field_type"] == "NUM":
              if first_obj["bbox"][0] - 2 < second_obj["bbox"][0] \
                and first_obj["bbox"][2] + 2 > second_obj["bbox"][0]:
                
                objects.remove(second_obj)
                hasChanges = True
                break
          else:
            if abs(first_obj["bbox"][0] - second_obj["bbox"][0]) < 10 \
              or abs(first_obj["bbox"][2] - second_obj["bbox"][2]) < 10 \
              or abs(first_obj["bbox"][2] - second_obj["bbox"][0]) < 10 \
              or abs(first_obj["bbox"][0] - second_obj["bbox"][2]) < 10 \
              or (first_obj["bbox"][0] < second_obj["bbox"][0] and first_obj["bbox"][2] > second_obj["bbox"][0]):
              
              if first_obj["text_value"] in second_obj["text_value"] \
                or second_obj["text_value"] in first_obj["text_value"]:
                continue

              new_x0 = min(first_obj["bbox"][0], second_obj["bbox"][0])
              new_x1 = max(first_obj["bbox"][2], second_obj["bbox"][2])
              new_y0 = min(first_obj["bbox"][1], second_obj["bbox"][1])
              new_y1 = max(first_obj["bbox"][3], second_obj["bbox"][3])
              bbox = (new_x0, new_y0, new_x1, new_y1)

              new_obj = {'field_type': first_obj["field_type"], 
                     'text_value': first_obj["text_value"] + " " + second_obj["text_value"],
                     'bbox': bbox, "pageNum": first_obj["pageNum"], "border_color": first_obj["border_color"]}

              objects.append(new_obj)
              objects.remove(first_obj)
              objects.remove(second_obj)
              hasChanges = True
              break
  return objects 

def handleNumbers(objects, im_height):
  type_objs = list(filter(lambda obj: obj['field_type'] == 'Number'
              and obj["bbox"][3] > 0, objects))
  type_objs = sorted(type_objs, key = lambda obj: obj['bbox'][3], reverse=True)
            
  if len(type_objs) == 0:
    return []
  
  if len(type_objs) > 3:
    type_objs = type_objs[0:3]
    
  if type_objs[0]['bbox'][3] > im_height * 2 / 3:
    type_objs[0]['field_type'] = 'MailOutcomeNumber'
  
    for index in range(1, len(type_objs)):
      type_objs[index]['field_type'] = 'Number' + str(index)
  else:
    for index in range(len(type_objs)):
      type_objs[index]['field_type'] = 'Number' + str(index)
    
  return type_objs
 
def handleDates(objects, im_height):
  type_objs = list(filter(lambda obj: obj['field_type'] == 'Date'
              and obj["bbox"][3] > 0, objects))
  type_objs = sorted(type_objs, key = lambda obj: obj['bbox'][3], reverse=True)
            
  if len(type_objs) == 0:
    return []
  
  if len(type_objs) > 3:
    type_objs = type_objs[0:3]
    
  if type_objs[0]['bbox'][3] > im_height * 2 / 3:
    type_objs[0]['field_type'] = 'MailOutcomeDate'
  
    for index in range(1, len(type_objs)):
      type_objs[index]['field_type'] = 'Date' + str(index)
  else:
    for index in range(len(type_objs)):
      type_objs[index]['field_type'] = 'Date' + str(index)
    
  return type_objs


def handlePersons(objects, im_height):
  top_person_objs = list(filter(lambda obj: (obj["field_type"] == "Person" 
                    and len(re.findall(r"[А-Я]", obj['text_value'])) >= 3
                    and len(re.findall(r"[А-Я]", obj['text_value'][0])) == 1
                    and (len(obj["text_value"].split(" ")) > 1 or len(obj["text_value"].split(".")) > 1)
                    and obj["bbox"][3] > im_height * 0.6), objects))
  top_person_objs = sorted(top_person_objs, key = lambda obj: obj["bbox"][3], reverse=True)
    
  bottom_person_objs = list(filter(lambda obj: (obj["field_type"] == "Person" 
                    and len(re.findall(r"[А-Я]", obj['text_value'])) >= 3
                    and len(re.findall(r"[А-Я]", obj['text_value'][0])) == 1
                    and (len(obj["text_value"].split(" ")) > 1 or len(obj["text_value"].split(".")) > 1)
                    and obj["bbox"][3] < im_height * 0.6), objects))
  bottom_person_objs = sorted(bottom_person_objs, key = lambda obj: obj["bbox"][3], reverse=False)
  
  other_person_count = 1
  
  if len(top_person_objs) > 6:
    top_person_objs = top_person_objs[0:6]
    
  for index in range(0, min(3, len(top_person_objs))):
    top_person_objs[index]["field_type"] = "ReceiverPerson" + str(index + 1)
    
  for index in range(3, len(top_person_objs)):
    top_person_objs[index]["field_type"] = "OtherPersons" + str(other_person_count)
    other_person_count += 1
    
  if len(bottom_person_objs) > 6:
    bottom_person_objs = bottom_person_objs[0:6]
    
  for index in range(0, min(3, len(bottom_person_objs))):
    bottom_person_objs[index]["field_type"] = "SenderPerson" + str(min(3, len(bottom_person_objs)) - index)
    
  for index in range(3, len(bottom_person_objs)):
    bottom_person_objs[len(bottom_person_objs) - 1 + 3 - index]["field_type"] = "OtherPersons" + str(other_person_count)
    other_person_count += 1
    
  top_person_objs = list(filter(lambda obj: (obj["field_type"] != "Person"), top_person_objs))
  bottom_person_objs = list(filter(lambda obj: (obj["field_type"] != "Person"), bottom_person_objs))
  
  return top_person_objs + bottom_person_objs


def handleOrgs(objects, im_height, im_width):
  objects_to_handle = objects.copy()
  receiver_objs = []
  for obj in objects:
    for receier_org_short in RECEIVER_ORGS:
      if receier_org_short in obj['text_value'].lower():
        obj['text_value'] = RECEIVER_ORGS[receier_org_short]
        receiver_objs.append(obj)
        
  objects_to_handle = [obj for obj in objects if obj not in receiver_objs]

  for index in range(len(receiver_objs)):
      receiver_objs[index]['field_type'] = 'ReceiverOrg' + str(index + 1)



  top_orgs_objs = list(filter(lambda obj: (obj["field_type"] == "Org" 
                      and (len(obj["text_value"].split(" ")) > 1 or len(obj["text_value"].split("«")) > 1)
                      and obj["bbox"][3] > im_height * 0.6), objects_to_handle))
  top_orgs_objs = sorted(top_orgs_objs, key = lambda obj: obj["bbox"][3], reverse=True)

  bottom_orgs_objs = list(filter(lambda obj: (obj["field_type"] == "Org" 
                      and len(obj["text_value"].split(" ")) > 1
                      and obj["bbox"][3] < im_height * 0.6
                      and obj["bbox"][3] > 0), objects_to_handle))
  bottom_orgs_objs = sorted(bottom_orgs_objs, key = lambda obj: obj["bbox"][3], reverse=False)
     
  other_org_count = 1
      
  if len(top_orgs_objs) > 1:
    top_left_orgs_objs = list(filter(lambda obj: obj["bbox"][0] < im_width * 0.45, top_orgs_objs))
    top_left_orgs_objs = sorted(top_left_orgs_objs, 
                  key = lambda obj: obj["bbox"][0], reverse=False)
    
    for index in range(0, min(3, len(top_left_orgs_objs))):
      top_left_orgs_objs[index]["field_type"] = "SenderOrg" + str(index + 1)
      
      
    top_right_orgs_objs = list(filter(lambda obj: obj["bbox"][0] > im_width * 0.45, top_orgs_objs))
    top_right_orgs_objs = sorted(top_right_orgs_objs, 
                  key = lambda obj: obj["bbox"][0], reverse=False)
    
    for index in range(0 + len(receiver_objs), min(3, len(top_right_orgs_objs))):
      top_right_orgs_objs[index]["field_type"] = "ReceiverOrg" + str(index + 1)
    
    top_left_orgs_objs = list(filter(lambda obj: (obj["field_type"] != "Org"), top_left_orgs_objs))
    top_right_orgs_objs = list(filter(lambda obj: (obj["field_type"] != "Org"), top_right_orgs_objs))
    
    return top_left_orgs_objs + top_right_orgs_objs + receiver_objs
    
  else:

    if len(top_orgs_objs) > 6:
      top_orgs_objs = top_orgs_objs[0:6]

    for index in range(0, min(3, len(top_orgs_objs))):
      top_orgs_objs[index]["field_type"] = "SenderOrg" + str(index + 1)

    for index in range(3, len(top_orgs_objs)):
      top_orgs_objs[index]["field_type"] = "Orgs" + str(other_org_count)
      other_org_count += 1

    top_orgs_objs = list(filter(lambda obj: (obj["field_type"] != "Org"), top_orgs_objs))

    return top_orgs_objs + bottom_orgs_objs + receiver_objs


def saveToXML(objects, docName, images, xml, maxPageNum):  
  font = ImageFont.truetype("Arsenal-Regular.otf", 20)

  unique_values = set()
  objects = [o for o in objects
      if (o['text_value'], o['field_type']) not in unique_values
      and not unique_values.add((o['text_value'], o['field_type']))]

  nums_objs = handleNumbers(objects, images[0].size[1])
  dates_objs = handleDates(objects, images[0].size[1])
  
  persons_objs = handlePersons(objects, images[0].size[1])
  orgs_objs = handleOrgs(objects, images[0].size[1], images[0].size[0])
  
  objects = nums_objs + dates_objs + persons_objs + orgs_objs
  
    
  for pageNum in range(0, maxPageNum):
    im_height = images[pageNum].size[1]
    image_drawer = ImageDraw.Draw(images[pageNum])
    
    for obj in objects:
      if obj["pageNum"] != pageNum:
        continue
      
      bbox = (obj["bbox"][0], int(im_height - obj["bbox"][1] - pageNum * 10000),
          obj["bbox"][2], int(im_height - obj["bbox"][3] - pageNum * 10000))

      image_drawer.rectangle((bbox[0], bbox[1], bbox[2], bbox[3] + random.randint(2, 10)), 
                  outline=obj["border_color"], width=3)
      
      image_drawer.rectangle((bbox[0], bbox[3], bbox[2], bbox[3]-20), fill="white")

      image_drawer.text((bbox[0], bbox[3]-20), obj["field_type"] + " | " + obj["text_value"], 
                font = font, fill=obj["border_color"])

      xml.write('  <{field_type} value="{value}" confidence="100" page="{page}" left="{x}" top="{y}" width="{w}" height="{h}"/>' \
            .format(field_type=obj["field_type"], value=obj["text_value"].replace('"', '').replace('<', '').replace('>', ''),
                x=bbox[2], y=bbox[1], w=bbox[2]-bbox[0], h=bbox[1]-bbox[3], page=pageNum)
            + '\n')
      
    images[pageNum].save("results/" + docName + "_" + str(pageNum) + ".jpg", "JPEG")

# %%
if __name__ == '__main__':
  MODEL_NAME = 'model'
  DPI_SCALE = 4.17
  STANDART_DPI = 72
  PDF_PATH = "input/"
  HANDLED_PATH = "handled/"
  SLEEP_TIME = 5

  border_colors = {
    'Number': 'red',
    'Date': 'deepskyblue',
    'Org': 'blue',
    'Person': 'green'
  }

  la_params = LAParams()
  la_params.line_margin = 1.6
  la_params.boxes_flow = 0.5

  createDirIfNotExist(PDF_PATH)
  createDirIfNotExist(HANDLED_PATH)
  createDir("results/", ".jpg")
  createDir("xmls/", ".xml")

  navec = Navec.load('vocab.tar')
  ner = NER.load(MODEL_NAME + '.tar')
  ner.navec(navec)

  while True:
      
    for doc_name in get_files(PDF_PATH, ".pdf"):
      images = convert_from_path(PDF_PATH + doc_name, dpi = STANDART_DPI * DPI_SCALE)

      fp = open(PDF_PATH + doc_name, 'rb')
      parser = PDFParser(fp)
      document = PDFDocument(parser)
      
      xml = io.open("xmls/" + doc_name.replace('.pdf', '') + ".xml", "w", encoding="utf-8")
      
      xml.write('<?xml version="1.0" encoding="UTF-8"?>' + '\n')
      xml.write('<idcard>' + '\n')

      drawnBoxes = []
      xmlsBoxes = []
      maxPageNum = 0
      
      for pageNum, page in enumerate(PDFPage.create_pages(document)):
        actName = doc_name.split(".")[0] + "_" + str(pageNum) 
        print(actName)
      
        rawText = ""
        text_lines = []

        
        rsr_mgr = PDFResourceManager()
        device = PDFPageAggregator(rsr_mgr, laparams=la_params)
        
        interpreter = PDFPageInterpreter(rsr_mgr, device)
        interpreter.process_page(page)
        
        layout = device.get_result()
        parse_obj(layout._objs, text_lines)

        processedText = re.sub(r"__+", r" ", rawText)

        # print("<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<")
        # if len(processedText) == 0:
        #   print("No text")
        # else:
        #   print(processedText)
        # print("<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<\n")
        


        if len(processedText) == 0:
          break

        markup = ner(processedText)
            
        extracted_nums = extractors.extractNums(processedText)
        highlightObjects(extracted_nums, 'Number')

        extracted_dates = extractors.extractDates(processedText)
        highlightObjects(extracted_dates, 'Date')

        extracted_orgs, extracted_persons = extractors.extractOrgs(markup)
        highlightObjects(extracted_orgs, 'Org')
        highlightObjects(extracted_persons, 'Person')

        extracted_persons = extractors.extractPersons(processedText, markup)
        highlightObjects(extracted_persons, 'Person')
           
        maxPageNum += 1
        
      saveToXML(xmlsBoxes, doc_name.replace('.pdf', ''), images, xml, maxPageNum)
      xml.write('</idcard>' + '\n')
      xml.close()

      fp.close()
      move(PDF_PATH + doc_name, HANDLED_PATH + doc_name)

    time.sleep(SLEEP_TIME)
# Out:
# letter_1_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# АРСЕНЬЕВСКАЯ  АВИАКОМПАНИЯ «ПРОГРЕСС»  ХОЛДИНГ ВЕРТОЛЕТЫ РОССИИ Акционерное общество  «Арсеньевская авиационная компания  «Прогресс» им. Н.П. Сазыкина»  (АО ААК «ПРОГРЕСС»)  пл. Ленина, д. 5, г. Арсеньев  Приморский край, 692335 Тел. +7(42361) 4-52-32. факс +7(42361) 4-50-93  ОГРН 1022500510350, ОКПО 07513814  ИНН 2501002394, КПП 250101001  e-mail: infofgiaacprouress.ru  vvww.inssianlielicopters.aero  //.202 / №  - язе. на №  О запуске в производство комплектующих  изделий для Ка-52М Генеральному директору Управляющей организации АО «Заслон» Горбунову А.А. Начальнику 286 ВП МО РФ Масленникову В.Н. ул. Коли Томчака, д. 9 г. Санкт-Петербург, 196006 Уважаемые Коллеги! На сегодняшний день с вашим предприятием заключены ведомости  поставки № 1, 2 от 06.07.2021 (далее по тексту - ведомость поставки)  к рамочному договору от 07.06.2021 № 518/10487 на поставку комплектующих  изделий, требуемых для изготовления вертолётов Ка-52М в рамках выполнения  государственного контракта от 30.09.2021 № 2126187424921412208210473. С учётом фактически произведенного авансирования по ведомостям  поставки в соответствии с платёжными поручениями: -  № 6934 от 24.08.2021; -  № 6935 от 24.08.2021; -  №7842 от 20.09.2021; -  № 7843 от 20.09.2021; -  № 8061 от 24.09.2021; -  № 8062 от 24.09.2021; -  № 8472 от 06.10.2021; -  № 8947 от 20.10.2021; -  № 8948 от 20.10.2021. Просим подтвердить запуск в производство соответствующих изделий,  а также готовность обеспечить их поставку в договорные сроки. Исполнитель: Кузнецова Людмила Владимировна Телефон: 8 (42361)4-52-87 E-mail: otd518@aacprogress.ru Вход. 514-7^?^ 23 -11» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 518/10487
# № 2126187424921412208210473.
# № 6934
# № 6935
# №7842
# № 7843
# № 8061
# № 8062
# № 8472
# № 8947
# № 8948
#
# Highlight Date
#  06.07.2021
#  07.06.2021
#  30.09.2021
#  24.08.2021
#  24.08.2021
#  20.09.2021
#  20.09.2021
#  24.09.2021
#  24.09.2021
#  06.10.2021
#  20.10.2021
#  20.10.2021
#  23 -11» 2021
#
# Highlight Org
# АВИАКОМПАНИЯ «ПРОГРЕСС»
# ХОЛДИНГ ВЕРТОЛЕТЫ
# Акционерное общество  «Арсеньевская авиационная компания  «Прогресс» им. Н.П. Сазыкина»
# АО ААК «ПРОГРЕСС»
# Управляющей организации АО «Заслон»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Кузнецова Людмила Владимировна Телефон
# Н.П. Сазыкина
# Горбунову А.А.
# Масленникову В.Н.
#
# -----------------------------------------------------
#
# letter_1_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Ваш ответ просим в возможно кратчайший срок направить на эл. адрес  otd518@aacprogress.ru. Директор по МТС НачальникШ230 ВП МО РФ П.А. Медведев Е.А. Пахомов
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
# МТС НачальникШ
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# П.А. Медведев
# Е.А. Пахомов
#
# -----------------------------------------------------
#
# letter_10_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ПУВПИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО Исх.№1002- <270<Х «о <28, Ю. Акционерное общество «Светлана-Электронприбор» 194156, Санкт-Петербург, Энгельса пр., д. 27 Лит,С пом.2-Н  телефон/фйкс: (812) 554 0380 ИНН 7802070277, КПП 780201001, ОГТП 1027801543241, ОКПО 31946633 р/с 40702810380000001580 в Филиал ОПЕРУ Балк ВТБ (ПАО) в Санкт-Петербурге БИК 044030704, к/с 30101810200000000704 c-mail: mail@svetlana-cp.ru  АКЦИОНЕРНОЕ ОБЩЕСТВО  «ЗАСЛОН» 196006, Санкт-Петербург,  ул.Коли Томчака, д. 9 Генеральному директору управляющему  организацией А.А.Горбунову Начальнику 286 ВП МО РФ В.Н.Масленникову Копия: Заместителю генерального директора по ГОЗ  и сервисному обслуживанию  А.П.Бобрышеву Копия: Заместителю генерального директора ПАО  «Компания «Сухой» С.Н.Панасенко Уважаемые Александр Анатольевич и Владимир Николаевич! С Уважением, Заместитель директора АО «Светлана - Электронприбор» Начальник 127 ВП МО РФ Подготовил Киселев С.Н. (812) 554-03-66 Вход. $ 514-^3^ 28 «10» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №1002-
#
# Highlight Date
#  28 «10» 2021
#
# Highlight Org
# ПУВПИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО Исх
# Ю. Акционерное общество «Светлана-Электронприбор» 194156
# Филиал ОПЕРУ Балк ВТБ (ПАО)
# ОБЩЕСТВО  «ЗАСЛОН»
# ПАО  «Компания «Сухой»
# АО «Светлана - Электронприбор
#
# Highlight Person
# АКЦИОНЕРНОЕ
# А.А.Горбунову
# Подготовил
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Уважаемые Александр Анатольевич
# Владимир Николаевич
# А.А.Горбунову
# В.Н.Масленникову
# А.П.Бобрышеву
# С.Н.Панасенко
# Киселев С.Н.
#
# -----------------------------------------------------
#
# letter_11_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Kj ■  i Публичное f УI LJJIEDI sHTroe набережная Академика Туполева, д.17  Москва, а/я 20, 105005  тел.: (499) 263-75-00 факс: (499) 263-77-01, (499) 263-77-02 ОКПО 18982156 ОГРН 1027739263056  ИНН 7705313252/КПП 774550001 № Исх-24109-55 На № от 01.12.2021  п/в АБД объекта ВП-021МСМ Заместителю генерального  АО «Заслон»  директора Майкову А.С. mfo@onegroup.ru Начальник 286 ВП МО РФ Масленникову В.Н. Уважаемый Александр Сергеевич! Уважаемый Владимир Николаевич В ответ на Ваш исх.№ 210-11583 от 03.11.2021 направляю Вам  уточнённую схему 342МСМ-7200-413, с учётом внесения дополнительного  потока для регистрации на ИИС-32-АБДМ от выходной линии 16 УБС №2,  разъема Х7:34(а),35(б). Приложение: Схема 342МСМ-7200-413 - на 1 листе, направлено по эл. виде.  Пароль от архива получить у исполнителя. Заместитель директора дирекции программ  военной авиации по программам самолетов  А. А. Блажаюк Винничек Святослав Андреевич  (499) 263-77-77 доб. 19-77
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № Исх-24109-55
# № 210-11583
#
# Highlight Date
#  01.12.2021
#  03.11.2021
#
# Highlight Org
# Kj ■  i Публичное f УI LJJIEDI sHTroe набережная Академика Туполева
# АО «Заслон»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Александр Сергеевич
# Владимир Николаевич
# Винничек Святослав Андреевич
# Майкову А.С.
# Масленникову В.Н.
# А. А. Блажаюк
#
# -----------------------------------------------------
#
# letter_12_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Руководителю РОССТАТ УПРАВЛЕНИЕ ФЕДЕРАЛЬНОЙ СЛУЖБЫ  ГОСУДАРСТВЕННОЙ СТАТИСТИКИ  ПО Г.САНКТ-ПЕТЕРБУРГУ И ЛЕНИНГРАДСКОЙ ОБЛАСТИ  Проф. Попова ул., д. 39, г. Санкт-Петербург, 197376  Тел.: (812) 230-75-20, факс: (812) 234-06-36  http://petrostat.gks.ru; E-mail: petrostat@gks.ru (ПЕТРОСТАТ) На №от  О проведении выборочного обследования  организаций о заработной плате работников  по профессиям и должностям за октябрь 2021 года В соответствии с Федеральным планом статистических работ на 2021 год,  утвержденным распоряжением Правительства РФ от 06.05.08 № 671-р (с измене­ ниями), проводится выборочное обследование но форме № 57-Т «Сведения о зара­ ботной плате работников по профессиям и должностям за октябрь 2021 года», ут­ вержденной приказом Росстата от 30.07.2021 № 457. Обследованию подлежат юридические лица (без субъектов малого  предпринимательства) и их обособленные подразделения всех форм  собственности. Согласно сформированной выборочной совокупности Ваша организация  (обособленное подразделение) вошла в число респондентов, подлежащих обследо­ ванию. Перечень подлежащих обследованию организаций по форме № 57-Т разме­ щен на портале Росстата: http://websbor.gks.ru/ Бланк формы № 57-Т, ХМТ-шаблон и электронная версия приказа Росстата  об утверждении формы размещены на официальном сайте Петростата по адресу:  https://petrostat.gks.ru/ Респондентам/ Формы федерального статистического на­ блюдения и формы бухгалтерской (финансовой) отчетности/ Альбом форм феде­ рального статистического наблюдения/ Рынок труда. Перед заполнением отчета необходимо внимательно ознакомиться с Указа­ ниями по его заполнению, размещенными на бланке формы. Форма № 57-Т состоит из двух разделов. В обязательном порядке должны  быть заполнены оба раздела отчета. Раздел I заполняется на всех работников орга­ низации (обособленного подразделения). Численность работников, подлежащих  индивидуальному обследованию в разделе II формы, зависит от числа работников,  полностью отработавших октябрь, и составляет от 8 до 64 человек.  „Вх. № 514-9107  от 22.11.2021
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 671-р
# № 57-Т
# № 457.
# № 57-Т
# № 57-Т
# № 57-Т
# № 514-9107
#
# Highlight Date
#  06.05.08
#  30.07.2021
#  22.11.2021
#
# Highlight Org
# Руководителю РОССТАТ УПРАВЛЕНИЕ ФЕДЕРАЛЬНОЙ СЛУЖБЫ  ГОСУДАРСТВЕННОЙ СТАТИСТИКИ  ПО Г.САНКТ-ПЕТЕРБУРГУ И ЛЕНИНГРАДСКОЙ ОБЛАСТИ  Проф. Попова ул
#
# Highlight Person
# Правительства
# Росстата
# Росстата
# Росстата
# Петростата
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Указа­
#
# -----------------------------------------------------
#
# letter_12_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Организациями. в которых численность работников полностью  отработавших октябрь, составляет 1000 человек и более заполняется еще вкладыш,  на котором сведения о работниках проставляются с порядковыми номерами от 33  до 64. В целях помощи по заполнению формы № 57-Т в Интернете  на официальном сайте Петростата размещено Пособие для кодирования профессий  рабочих и должностей служащих в выборочном обследовании организаций о зара­ ботной плате работников за октябрь 2021 г., составленное на основе (ЖИД ГР по  адресу: https://petrostat.gks.ru/ Респондентам/ Формы федерального статистического  наблюдения и формы бухгалтерской (финансовой) отчетности/ Альбом форм феде­ рального статистического наблюдения/ Рынок груда / Форма № 57-Т. В соответствии с Федеральным законом от 31.12.2020 г. № 500 ФЗ «О  внесении изменений в Федеральный закон «Об официальном статистическом учете  и системе государственной статистики в Российской Федерации» (от 29.11.2007  года №282-ФЗ) с 30 декабря 2020 года все юридические лица и граждане,  осуществляющие предпринимательскую деятельность без образования  юридического лица (индивидуальные предприниматели), обязаны представлять  первичные статистические данные но формам федерального статистического  наблюдения исключительно в форме электронного документа, подписанного  электронной подписью. При этом организация может представить Форму № 57-Т в электронном виде  следующими способами: - через специализированных операторов связи; через систему Web-сбора в режиме on-line или off-line (подробности на  сайте Петростата по адресу: https://petrostat.gks.ru/ Респондентам/ Статистическая  отчетность в электронном виде/ Система Web-сбора); Срок предоставления формы не позднее 30 ноября 2021 года. Акцентируем Ваше внимание, что нарушение порядка представления стати­ стической информации или представление недостоверной информации влечет от­ ветственность, установленную статьей 13.19 Кодекса РФ об административных  правонарушениях от 30.12.2001 № 195-ФЗ (с изменениями и дополнениями от 30  декабря 2015 № 442-ФЗ). Заместитель руководителя С.В. Черных Зыкова Елена Александровна,  (812) 230-35-40 Кунтышева Людмила Игоревна. (812) 234-07-42 Отдел социальной статистики
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 57-Т
# № 57-Т.
# № 500
# №282-ФЗ)
# № 57-Т
# № 195-ФЗ
# № 442-ФЗ).
#
# Highlight Date
#  31.12.2020
#  29.11.2007
#  30 декабря 2020
#  30 ноября 2021
#  30.12.2001
#  30  декабря 2015
#
# Highlight Org
# Форму № 57-Т
# С.В. Черных Зыкова
# Отдел социальной статистики
#
# Highlight Person
# Интернете
# Петростата
# Петростата
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Елена Александровна
# Людмила Игоревна
# С.В. Черных
#
# -----------------------------------------------------
#
# letter_13_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ЧКЦИОНЕРНОЕ ОБЩЕСТВО «СЕВЕРО-Г\П \ДНЫЙ РЕГИОНАЛЬНЫЙ ЦЕНТР  КОНЦЕРН А ВКО « V IMA 1 - АНТЕЙ» - ОБУХОВСКИЙ ЗАВОД» ic.1 факс: < Ml » 5hJ-9S • I i c-ni:iil. Фчн: go/.ru 1‘>2<|Ц. Рис», ня. < .‘.iiiki I к'••.‘J'1 Л Hp.’Viicsi I >6у'.,чк|.-,.ч| <ь5чри;1| •. 1?н. 1е.<сф-Ш i-'lli  1 2.11.2021 s  На №60-10133 от 20.09.2021г.  О"? I IM I’H Н>ГК2'Ч'.Ч7<', lllill Kllil "Si I I4J64K 7‘Н|1^П1и] < H>;icli.is-.Xv < >b,Hum pi., 11" >I-t’cn-r-.bP.ii'-.U. 111 J"I 2. id iS k’i kd-’^.-Vl, ;d I.o, <SI ll ЗМ-Чч.|!. e ni.BJ .Iouj t'-'/.ni Управляющему директору АО «Заслон» Адаменя А.И. 196006, г. Санкт-Петербург,  ул. Коли Томчака, д.9  Тел.:(812)327-90-99  Факс:(812)324-61-00  e-mail: info@onegroup.ru На Ваш исх. №60-10133 от 20.09.2021г. сообщаю, что на АО «Обуховский  завод» отсутствует техническая возможность выполнения данного запроса. С уважением, Первый заместитель  генерального директора-  технический директор В.В. Шафранский Исп. Шубина Мария Борисовна  тел. (812) 363-92-96 Г\!= 1 п
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №60-10133
# №60-10133
#
# Highlight Date
#  2.11.2021
#  20.09.2021
#  20.09.2021
#
# Highlight Org
# ЧКЦИОНЕРНОЕ ОБЩЕСТВО «СЕВЕРО-Г\П \ДНЫЙ РЕГИОНАЛЬНЫЙ ЦЕНТР  КОНЦЕРН А
# ОБУХОВСКИЙ ЗАВОД»
# АО «Заслон»
# АО «Обуховский  завод
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Шубина
# Мария Борисовна
# Адаменя А.И.
# В.В. Шафранский
#
# -----------------------------------------------------
#
# letter_14_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# АКЦИОНЕРНОЕ ОБЩЕСТВО ЛЕТНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ  • GROMOV FLIGHT RESEARCH INSTITUTE о ГОСУДАРСТВЕННЫЙ НАУЧНЫЙ ЦЕНТР РОССИЙСКОЙ ФЕДЕРАЦИИ имени М.М. ГРОМОВА Управляющему директору  АО «ЗАСЛОН»    Адамене А.И.  РФ, 196006, г. Санкт-Петербург, ул. Коли Томчака, д.9, лит. Н, о/я 167 ГРУППА КОМПАНИЙ ОАК На №от Об исполнении обязательств Уважаемый Анатолий Иванович! Направляю Вам для подписания два экземпляра акта приема-передачи (возврата)  по Договору аренды от 24 декабря 2020 г. №7049197013а (часть нежилого помещения Приложение: по тексту на 2-х листах. Генеральный директор Е.Ю. Пушкарский 056460 ППППППППШППШПШ РОССИЙСКАЯ ФЕДЕРАЦИЯ 140180, О МОСКОВСКАЯ ОБЛАСТЬ, г.ЖУКОВСКИЙ. ул. ГАРНАЕВА, д. 2А ШПШШПШШШПНШ  Our address: Russian Federation о 140180, Gamacv str, bld.2A, Zhukovsky, Moscow Region  О ТЕЛЕФОН ДЛЯ СПРАВОК: (495) 556-59-38 О ФАКС: (495) 556-70-70 о Contact telephons: (495) 556-59-38, Fax: (495) 556-70-70 e-mail: secretarv.chief@lii.ru Исполнитель: Дронова Наталья Вячеславовна Телефон: 8 (495) 556-53-53
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №7049197013а
#
# Highlight Date
#  24 декабря 2020
#
# Highlight Org
# АКЦИОНЕРНОЕ ОБЩЕСТВО ЛЕТНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ  • GROMOV FLIGHT RESEARCH INSTITUTE о ГОСУДАРСТВЕННЫЙ НАУЧНЫЙ ЦЕНТР РОССИЙСКОЙ ФЕДЕРАЦИИ имени М.М. ГРОМОВА
# АО «ЗАСЛОН»
# ГРУППА КОМПАНИЙ ОАК
# ППППППППШППШПШ РОССИЙСКАЯ ФЕДЕРАЦИЯ
#
# Highlight Person
# Управляющему
# Zhukovsky
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Анатолий Иванович
# Дронова
# Наталья Вячеславовна Телефон
# М.М. ГРОМОВА
# Адамене А.И.
# Е.Ю. Пушкарский
#
# -----------------------------------------------------
#
# letter_14_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# приема-передачи  (возврата Объекта аренды) г. Жуковский 2021 г. Стороны установили (не установили) следующие недостатки:  Арендодатель: Генеральный директор АО «ЛИИ им. М.М. Громова» Арендатор: Управляющий директор АО «ЗАСЛОН» (Е.Ю. Пушкарский) 2021 г. 2021 г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
# Объекта аренды
# АО «ЛИИ им. М.М. Громова
# АО «ЗАСЛОН»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# М.М. Громова
# Е.Ю. Пушкарский
#
# -----------------------------------------------------
#
# letter_15_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# AAE /  Исх. №  На исх. №от Организация электрического  и информационного сопряжения  изделий на заказе проекта 20386 Акционерное общество Научно-производственное предприятие «Авиационная и Морская Электроника» (АО НПП «АМЭ») ул. Маршала Говорова, д. 29, литер 0, пом. 7-Н, офис 70, Санкт-Петербург, 198095  Почтовый адрес а/я 51, Санкт-Петербург, 198097  Тел.: (812) 339-91-10, факс: (812) 327-46-67, https://www.nppame.com, e-mail: mail@nppame,ru  ОКП011141092; ОГРН 1037841007896; ИНН/КПП 7819029855/780501001 Техническому директору ЗАО «Си Проект»  Соловьеву М.А. e-mail: info@seaproiect.ru Генеральному конструктору  радиоэлектронного вооружения ВМФ  АО «ЗАСЛОН» Киселеву В.А. E-mail: info@onegroup.ru Главному инженеру АО «ЦМКБ «Алмаз» Голубеву К.Г. e-mail: office@almaz-kb.ru Исполнительному директору АО «НИИРПИ» Бочарову Д.Р. e-mail: niirpi@niirpi.com Уважаемый Михаил Анатольевич! Уважаемый Владимир Анатольевич! Уважаемый Константин Геннадьевич! Уважаемый Денис Робертович! Предлагаю провести совещание по вопросу организации информационного  обмена между изделиями Вашей разработки через единую информационную  корабельную сеть (ЕИКС) на заказе проекта 20386. Суть проблемы, необходимой для решения на совещании - организация  передачи данных между изделиями через две сети - КСОН из состава изделия  СОЭЖ-20386 и ЕИКС из состава изделия ИС ГКП-20386, имеющие разные правила  и организацию передачи данных. Ранее для сопряжения изделий КСОН-20386 и МДА-7 из состава ИС ГКП-  20386 были согласованы протоколы сопряжения, предназначенные для получения Исп.: Седов Андрей Алексеевич  вход.л 514- SVsSf 8(812)339-91-10 (доб. 1214) 10 .11-2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#  10 .11-2021
#
# Highlight Org
# Акционерное общество Научно-производственное предприятие «Авиационная и Морская Электроника»
# АО НПП «АМЭ»
# ЗАО «Си Проект
# АО «ЗАСЛОН»
# АО «ЦМКБ «Алмаз»
# АО «НИИРПИ»
# ИС ГКП-
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Маршала Говорова
# Михаил Анатольевич
# Владимир Анатольевич
# Константин Геннадьевич
# Денис Робертович
# Седов Андрей Алексеевич
# Соловьеву М.А.
# Киселеву В.А.
# Голубеву К.Г.
# Бочарову Д.Р.
#
# -----------------------------------------------------
#
# letter_15_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# изделием МДА-7 данных от корабельных систем, сопряженных через КСОН.  Поэтому сопряжение было организовано по правилам КСОН. При организации передачи данных от КСОН изделиям СУ МФ РЛК и  ОНЦ/МФ РЛК, сопрягаемых с другими изделиями корабля через ЕИКС и по  правилам ЕИКС, ранее согласованные протоколы КСОН - МДА-7 не работают, о  чем сообщалось в АО «Заслон» письмом исх.№ 360-7602 от 28.07.2021г. Организация передачи данных между изделиями заказа через ЕИКС  отработана на кораблях заказов 20385 (зав.№ 1005) и 20380 (зав. № 2103). Изделие  ИС ГКП, в состав которого входит ЕИКС, имеет литеру О1; заканчивается  процедура сертификации изделия ЕИКС в системе сертификации МО РФ. Совещание предлагаю провести 24.11.2021г. в 11.00. О согласии принять участие в совещании, ФИО участников прошу  сообщить до 22.11.2021 г. С уважением, главный конструктор ИС ГКП Г.Г. Божченко
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 360-7602
# № 1005)
# № 2103).
#
# Highlight Date
#  28.07.2021
#  24.11.2021
#  22.11.2021
#
# Highlight Org
# АО «Заслон»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Г.Г. Божченко
#
# -----------------------------------------------------
#
# letter_16_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Исх. № 457/21  от 08.11.2021г. Общество с ограниченной ответственностью 191144, г. С-Петербург, Моисеенко ул., д.22, тел/факс 702-52-20 «Авионика-Вист» E-mail: avionika-vist@yandex.ru Коммерческому директору  АО «Заслон»    Григорьеву Е.П.  196084, Санкт-Петербург, ул. Коли Томчака, д. 9  тел/факс: (8812)324-61-00 Начальнику 286 ВП МО РФ  Масленникову В.Н. Уважаемый Евгений Павлович! Уважаемый Владимир Николаевич! На Ваше письмо (исх. №680-11253 от 28.10.2021г.) сообщаю, что  запрашиваемые Вами блоки содержат ОКБ ИП. Для переоформления паспортов с  записью «годен для эксплуатации» в соответствии с вышеуказанным письмом  прошу сообщить о порядке выполнения мероприятий, предусмотренных  «Временной Инструкцией о порядке применения продукции иностранного  производства в образцах вооружения, военной и специальной техники (их  унифицированных составных частях)» утвержденной Заместителем Министра  Обороны Российской Федерации 29 июля 202 Иода. Приложения: Перечни ЭКБ ИП входящей в модули питания на М л. Генеральный директор В.Г. Коко ул ин Согласовано:  Начальник 257 военного представительства  Министерства обороны Российской Федерации п  А.В. Данилов Вх. N2514-8796 11.11.2021
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 457/21
# №680-11253
#
# Highlight Date
#  08.11.2021
#  28.10.2021
#  29 июля 20
#  11.11.2021
#
# Highlight Org
# Общество с ограниченной ответственностью 191144
# Моисеенко ул
# АО «Заслон»
# ОКБ ИП
# Перечни ЭКБ ИП
# В.Г. Коко ул ин Согласовано
# Министерства обороны
#
# Highlight Person
# Авионика-Вист
# Обороны
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Евгений Павлович
# Владимир Николаевич
# Григорьеву Е.П.
# Масленникову В.Н.
# А.В. Данилов
#
# -----------------------------------------------------
#
# letter_16_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ЭРИ ИП для изделия МВП 5/15 БЕЖК436434.069 Обозначение типа (типономинала) Фирма изготовитель Конденсатору Функциональное  назначение Основные параметры Конструктивное  исполнение Диапазон рабочих температур Кол-во в одном  образце Примечание TAJA225 К 010 R ГА' 10 В 2.2 мкФ) AVX. США Танталовый конденсатор TAJB106K010R ГВ'10 В 10 мкФ) AVX. США Танталовый конденсатор TAJD107 К 010 R ГО' 10 В 100 мкФ) AVX, США Танталовый конденсатор TAJD337 М 010 R ГО' 10 В 330 мкФ) AVX. США Танталовый конденсатор TAJC685 К 020 R ГС' 20 В 6.8 мкФ) AVX, США Танталовый конденсатор 293D106X9050E2W СЕ' 50 В 10 мкФ) VISHAY. США Танталовый конденсатор 0805 5А101КАТ2А (ЧИП 0805 NPO 50 В 100 пФ) AVX. США Конденсатор 0805 5А221КАТ2А (ЧИП 0805 NPO 50 В 220 пФ) AVX, США Конденсатор СМ21 CG102K50AT (ЧИП 0805 NPO 50 В 1000 пФ) AVX. США Конденсатор 0М21 CG222K50AT (ЧИП OS05 NPO 50 В 2200 пФ) AVX. США Конденсатор )805 5С472КАТ2А (ЧИП 0805 X7R 50 В 4700 пФ) AVX. США Конденсатор ,DR31 ВХЮЗАКММ (ЧИП 0805 X7R 50 В 0.01 мкФ) AVX, США Конденсатор Для поверхностного монтажа с высокой ударной прочностью. Напряжение U = 10 В. Емкость С = 2.2 мкФ. Отклонение от номинала ±10%. Для поверхностного монтажа с высокой ударной прочностью. Напряжение U ■ 10 В Емкость С * 10 мкФ Отклонение от номинала ±10% Для поверхностного монтажа с высокой ударной прочностью. Напряжение U = 10 В. Емкость С = 100 мкФ. Отклонение от номинала ±10% Для поверхностного монтажа с высокой ударной прочностью. Напряжение U ■ 10 В. Емкость С ■ 330 мкФ. Отклонение от номинала ±10%. Для поверхностного монтажа с высокой ударной прочностью. Напряжение U = 20 В. Емкость С = 6.8 мкФ. Отклонение от номинала ±10%. Напряжение U = 50 В. Емкость С = 10 мкФ Отклонение от номинала ±10%. Керамический. Напряжение U = 50 В. Емкость С = 100 пФ Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ = ±15 %. Керамический Напряжение U - 50 В. Емкость С = 220 пФ Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ ■ ±15 %. Керамический Напряжение U = 50 В Емкость С» 1000 пФ. Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ = ±30 рртЛС. Керамический. Напряжение U ■ 50 В. Емкость С = 2200 пФ Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ « ±30 рртЛС. Керамический. Напряжение U = 50 В. Емкость С ■ 4700 пФ Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ ■ ±15 %. Керамический Напряжение U = 50 В. Емкость С = 0,01 мкФ. Отклонение от номинала ±10%. Температурный коэффициент емкости ТКЕ я ±15 %. Корпус "А" размер  3.2x1.6x1.6 мм от минус 55°С до + 85"С Корпус 'В' размер 3 5x2 8x1 9 мм от минус 55'С до ♦ 85*С Корпус "D" размер  7 3x4 3x2.9 мм от минус 55°С до * 85"С Корпус "D” размер  7 3x4 3x2 9 мм от минус 55°С до ♦ 85*С Корпус Х“ размер  6 0x3 2x2 6 мм от минус 55'С до ♦ 85"С 7.3x4 3x4 мм от минус 55'С до ♦ 85*С Размер 0805 от минус 55’С до* 125*С Размер 0805 от минус 55°Сдо* 125*С Размер 0805 от минус 55'С до* 125*С Размер 0805 от минус 55“С до ♦ 125*С Размер 0805 от минус 55’С до ♦ 125Х Размер 0805 от минус 55'С до* 125'С
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
# ЭРИ ИП
#
# Highlight Person
# VISHAY
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Конденсатору Функциональное
# Танталовый
# Конденсатор
# Конденсатор
# Конденсатор Для
#
# -----------------------------------------------------
#
# letter_16_2
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# 2SA1162  TOSHIBA. Япония Транзистор IRFI640G    Другое International Rectifier, США Т ранзистор Индуктивность В82432-Т1103-К (ЧИП 1812 ЮмкГн)  SIEMENS. Германия Индуктивность Биполярный р-п-р. Напряжение коллектор-эмиттер UR3 = 50 В. Ток коллектора I» = 150 мА. Коэффициент усиления 70-400. л-канальный MOSFET с изолированным затвором  Напряжение сток-исток = 200 В. Ток стока 10 = 9.8 А Сопротивление открытого канала Rds^ = 0.18 Ом. Индуктивность L = 10 мкГн. Омическое сопротивление R = 0.35 Ом. Ток лодмагн. I = 650 мА. ТО-236 MOD от минус 55’С до +125*С ТО-220 от минус 55*С до *125*С Размер 1812 от минус 40”С до ♦ISO’C
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
#
# Highlight Person
# TOSHIBA
# SIEMENS
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Т ранзистор Индуктивность
# Индуктивность Биполярный
#
# -----------------------------------------------------
#
# letter_17_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# GROUP JSC ZASLON Letter H, 9, Koli Tomchaka str. 9 P/О BOX 167 Saint-Petersburg, 196006 Russia For the attention of Mr. A. I. ADAMENYA,  (Managing Director) O/Ref.: 21DPP125/18-GDM-0197/ JMF Y/Ref.: Contract No 1418187404941020105004105_4 Object: Sea trials Novorossiysk October 12th, 2021 Dear Sir, We acknowledge your notification of work (Letter Ref 1100-10106 dated 28 Sept 2021) to send ECA  specialists to Novorossiysk to complete works on Serial Ship S/N 524 from 18 October 2021. Unfortunately, we regret to tell you that ECA team is not available for this period. This is due to a constant  rescheduling of our activities which are not still all stabilized with Covid situation (delay in goods supplying,  constraints to travel, sanitary constraints, ...). ECA team has suffered of this situation and previous  activities have been delayed. On the other side we are still waiting for an official export control authorization to deliver parts for repair.  Without this authorization it is no more possible for ECA to deliver goods in Russia. ECA team could be available in December 2021 for a mission in Novorossiysk (under condition that  authorization for goods are granted) to achieve all remaining works on the DIAMOND system including  sea trials. ECA do its best to reduce this delay and to limit the possible binding effects on your industrial  organization. Kind regards FOUILLIARD Jean-Marc Signature numerique de  FOUILLIARD Jean-Marc  Date: 2021.10.13 17:00:38  +02'00’ Jean-Marc FOUILLIARD Project Manager Вход. № ECA Robotics Siege social/Head office: 262 rue des freres Lumiere, Z.L Toulon Est, 83130 La Garde, France TOULON • Adresse postale/Postal address: 262 rue des freres Lumiere, Z.L Toulon Est, BP 242, 83078 Toulon Cedex 9, France Tel/Phone: +33 4 94 08 90 00 • Fax: +33 4 94 08 90 70 • eca-robotics-toulonfdecagroup.com • www.ecagroup.com UNE SOCItTE DU CROUPE CORCE SA.S.U. au capital de 13 795305euros • RCS TOULON 509232591ISIRET 509232 591 000241 • APE3011Z-TVA Intracommunautaire: FR68 509 232 591  A CROUPE CORCE COMPANY
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № ECA
#
# Highlight Date
#  94 08 90
#  94 08 90
#
# Highlight Org
# Z.L Toulon Est
# La Garde
# France TOULON • Adresse
# Z.L Toulon Est
# BP 242, 83078 Toulon Cedex 9
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
#
# -----------------------------------------------------
#
# letter_18_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# РЫБИНСКИЙ ЗАВОД  ПРИБОРОСТРОЕНИЯ АКЦИОНЕРНОЕ ОБЩЕСТВО «РЫБИНСКИЙ ЗАВОД ПРИБОРОСТРОЕНИЯ»  ПРЕДПРИЯТИЕ КОНЦЕРНА «ВЕГА» 152907, проспект Серова, д. 89, г. Рыбинск, Россия Тел.:+7(4855)28-51-51 Факс: +7(4855)28-58-03 E-mail: pribor@rzp.su Web: www.rzp.su ZZ ZZ и?/Исх. №012/ Заместителю генерального директора АО «ЗАСЛОН» А.И. Адамене Адрес: 196084, Россия,  г. Санкт-Петербург  ул. Коли Томчака, 9, а/я 167  Факс: 8(812) 324-61-00  E-mail: info@onegroup.ru Уважаемый Анатолий Иванович! Направляю Вам согласованный с нашей стороны протокол разногласий к договору №  2023187420281412208203565/425/4-21 от 16.06.2021 года. Приложение: - протокол разногласий - 1 экз., на 1-ом листе. С уважением, Директор по коммерческой деятельности Б.Р. Трофимов Исп. Голубев С.В.. Тел. (4855) 55-02-98  Моб. +7 903-821-66-69 E-mail: osb@rzp.su
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №012/
#
# Highlight Date
#  16.06.2021
#  55-02-98
#
# Highlight Org
# РЫБИНСКИЙ ЗАВОД  ПРИБОРОСТРОЕНИЯ АКЦИОНЕРНОЕ ОБЩЕСТВО «РЫБИНСКИЙ ЗАВОД ПРИБОРОСТРОЕНИЯ»  ПРЕДПРИЯТИЕ КОНЦЕРНА «ВЕГА»
# АО «ЗАСЛОН»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Анатолий Иванович
# А.И. Адамене
# Б.Р. Трофимов
# Голубев С.В.
#
# -----------------------------------------------------
#
# letter_18_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# к Договору №2023187420281412208203565/425/4-21 от 16.06.2021 г. ПРОТОКОЛ РАЗНОГЛАСИЙ » сентября 2021 г. г. Санкт-Петербург Акционерное общество «Рыбинский завод Приборостроения» (АО «РЗП»), именуемое в дальней­ шем «Поставщик», в лице директора по коммерческой деятельности Трофимова Б.Р., действующего на ос­ новании доверенности №57 от 16.04.2021 г, с одной стороны, и Акционерное общество «ЗАСЛОН», именуемое в дальнейшем «Заказчик», в лице Управляющего ди­ ректора Адамени А.И., действующего на основании доверенности № 83 от 14.12.2020 г., с другой стороны,  совместно именуемые Стороны, заключили настоящий протокол разногласий к Договору №  2023187420281412208203565/425/4-21 от 16.06.2021 г. (далее - Договор), о нижеследующем: Пункт  Редакция По­ ставщика Договора По тексту догово­ Пункт 3.1 Пункт 6.2. По тексту догово­ Редакция Заказчика Пункт 9.1. По тексту догово­ Пункт 13 По тексту догово­ Пункт 9.1, изложив в следующей редакции: «Все споры, разногласия  и требования, возникающие из настоящего договора или в связи с  ним, в том числе касающиеся его исполнения, нарушения, изменения,  прекращения и недействительности, подлежат разрешению в арбитраж­ ном суде по месту нахождения истца» 1ункт 13. Адреса и реквизиты изложить в следующей редакции: 2. При подписании Настоящего Протокола разногласий стороны договорились принять редакцию Заказчика. 1-
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №2023187420281412208203565/425/4-21
# №57
# № 83
#
# Highlight Date
#  16.06.2021
#  16.04.2021
#  14.12.2020
#  16.06.2021
#
# Highlight Org
# Договору №2023187420281412208203565/425/4-21
# Рыбинский завод Приборостроения»
# АО «РЗП»
# Акционерное общество «ЗАСЛОН»
# Договору №  2023187420281412208203565/425/4-21
#
# Highlight Person
# Поставщик
# Заказчик
# Заказчика
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Трофимова Б.Р.
# Адамени А.И.
#
# -----------------------------------------------------
#
# letter_19_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Генеральному директору  акционерного общества «Заслон»  А.А.ГОРБУНОВУ  ул. Коли Томчака, д. 9,  г. Санкт-Петербург, 196006 Уважаемый Александр Анатольевич! В связи с обострившейся эпидемиологической обстановкой и в целях  недопущения распространения коронавирусной инфекции (COVID-19)  56-я Межведомственная военно-научная конференция на тему: «Ракетные  войска и артиллерия в современных военных конфликтах и войнах будущего»  будет проведена в заочной форме. Поступившие в адрес академии материалы докладов будут  опубликованы в сборнике трудов конференции. С уважением, Начальник Михайловской военной артиллерийской академии  генерал-лейтенант  «Л> ноября 2021 г. Исх.№ аУ/У С.Баканеев
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № аУ/У
#
# Highlight Date
#
# Highlight Org
# Михайловской военной артиллерийской академии
#
# Highlight Person
# Заслон»
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Александр Анатольевич
# С.Баканеев
# А.А.ГОРБУНОВУ
#
# -----------------------------------------------------
#
# letter_2_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Акционерное Общество  (АО «Элкус») 196128, Санкт-Петербург, ул. Благодатная, 10 стр. 1. Р/с 40702810455160040735 в Северо-Западный Банк ОАО «Сбербанк России» г. Санкт-Петербург,  к/с 30101810500000000653 БИК 044030653 ОКПО 23125023, ОКОНХ 95120 ОГРН 1027804181965 ИНН 7806002060, КПП 781001001 « Qi  2021г. Исх. № У/У/ Тел./факс Ш 2) 369-16-41; 369-01-04; 324-60-91 E-mail: mail@elcus.ru «Электронная компания «Элкус»  Первому заместителю генерального  директора- генеральному конструктору  АО «ЗАСЛОН» A. И. Живецу Копия Начальнику 286 ВП МО РФ B. Н. Масленникову 196006, Россия, г.Санкт-Петербург, ул. Коли Томчака, д.9 тел. (812) 327-90-99 факс (812) 324-61-00 Уважаемый Андрей Иванович! Уважаемый Владимир Николаевич! BOX-8GTP-M ГФКП.468351.048 зав.№ 0487 Направляем в адрес вашего предприятия дубликат этикетки на изделие ESP-  Основание для оформления дубликата исходящий от 28.10.2021г. № 910-11286. С уважением, Технический директор В.В. Голубев исп. Ермолов В. М. (812) 610-18-84 доб. 019
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № У/У/
# № 0487
# № 910-11286.
#
# Highlight Date
#  28.10.2021
#
# Highlight Org
# Акционерное Общество  (АО «Элкус»
# Северо-Западный Банк ОАО «Сбербанк России
# АО «ЗАСЛОН»
# Копия Начальнику 286 ВП
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Андрей Иванович
# Владимир Николаевич
# A. И. Живецу
# B. Н. Масленникову
# В.В. Голубев
# Ермолов В. М.
#
# -----------------------------------------------------
#
# letter_20_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ' ЛЕТД/  АКЦИОНЕРНОЕ ОБЩЕСТВО Иркутский релейный завод Россия, 664075, г. Иркутск, ул. Байкальская, 239, тел.: приемная - (3952) 22-60-30;  сбыт - т/ф (3952) 24-76-19/ 24-57-45; маркетинг - т/ф (3952) 35-23-18/ 24-56-46; E-mail: marketing@irzirk.ru, http://www.irzirk.ru Baikalskaya str., 239, Irkutsk, 664075, Russia, tel.: (7-395-2) 226-030, fax 245-745. ОКПО 07525591; ОГРН 1023801537792; ИНН 381 1016215; КПП 381101001 При ответе ссылайтесь на наш номер  №710/2311 от 15.11.2021г. АО «ЗАСЛОН» 196006, Санкт-Петербург г, Коли Томчака  ул, дом 9 Для Алексеева А.В. Высылаем в ваш адрес подписанные спецификации к договору № 710/906 от 02.07.21г. на  поставку реле и переходов в 2021 г. Просим один подписанный экземпляр вернуть в наш адрес. Приложение: 1. Спецификация № 3 от 08.11.2021 г. - 2 экз.. Начальник ФСО Афанасьева Н.В. Исп. Самойлова О.Г. (3952) 245-745 Вход. № 22 “11* 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №710/2311
# № 710/906
# № 22
#
# Highlight Date
#  15.11.2021
#  02.07.21
#  08.11.2021
#  22 “11* 2021
#
# Highlight Org
# АО «ЗАСЛОН»
#
# Highlight Person
# Irkutsk
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Алексеева А.В.
# Афанасьева Н.В.
# Самойлова О.Г.
#
# -----------------------------------------------------
#
# letter_20_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Наименование продукции, ТУ, ОСТ...* Вилка СР-50-805ИрФД ФИМД.430421.002 ТУ 5 Вилка СР-50-875ИрФМ ФИМД.430421.002 ТУ 5 СПЕЦИФИКАЦИЯ №3 от 08.11.2021  к договору №710/906 от 02.07.2021 Цена за ед. без  НДС (руб.) 1533,91 914,5 ИТОГО Сумма НДС 20%:  18 017,74 руб. Сумма с учетом НДС: 108 106,42 руб. Объем  поставки, (шт.) Приложение 1 к договору  №710/906 от  02.07.2021 Стоимость без  НДС (руб.) 73 627,68 16 461,00 90 088,68 Во исполнение ГОЗ №1922187320321452208002620 от 05.04.2019г. Срок поставки продукции в течение 60 банковских дней с момента поступления 100% предоплаты на счет Поставщика. ПОКУПАТЕЛЬ Управляющий директор  Адаменя А.И. НАЧАЛЬНИК 286 ВП МО РФ Масленников В.Н. *Для изделий "ОС”, "ОСМ", "ОСД" Исп.Самойлова Ольга Геннадьевна
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №710/906
# №710/906
# №1922187320321452208002620
#
# Highlight Date
#  08.11.2021
#  02.07.2021
#   02.07.2021
#  05.04.2019
#
# Highlight Org
# Адаменя А.И. НАЧАЛЬНИК
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Ольга Геннадьевна
# Адаменя А.И.
# Масленников В.Н.
#
# -----------------------------------------------------
#
# letter_21_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# 25 Ноя ZOZ1 13:54 Факс 8-863-Z50-53-58 Стр.: 1 «РОСТОВСКИЙ-НА-ДОНУ НАУЧНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ РАДИОСВЯЗИ»  ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ УНИТАРНОЕ ПРЕДПРИЯТИЕ  ФЕДЕРАЛЬНЫЙ НАУЧНО-ПРОИЗВОДСТВЕННЫЙ ЦЕНТР  Российская Федерация, 344038, г. Ростов-на-Дону, ул. Нансена, д. I30  тел. (863) 2000-555, 2555-311, факс 2000-500, тлг. 123119 «Вектор» ФАКСИМИЛЬНОЕ СООБЩЕНИЕ 2021 г. исх. №130/6^6  «25»  КОМУ: Главному инженеру АО «ЦМКБ «Алмаз» К.Г. Голубеву КОПИЯ: Генеральному конструктору  радиоэлектронного вооружения ВМФ  АО «ЗАСЛОН» В.А. Киселеву НОМЕР ФАКСА: (812) 369-59-25 (812) 324-61-00 Число страниц, включая титульную: 1 Начальника научно-технического комплекса ФГУП «РНИИРС» А.С. Митькина НОМЕР ФАКСА: (863) 255-52-53 Уважаемый Константин Геннадьевич! На Ваш исходящий №15-562-18573-2021 от 22.11.2021 сообщаю, что все  документы актуальны на настоящий момент и будут поставлены на  абонентский учет после заключения дополнительного соглашения №1 к  договору №31О-127у.2О от 01.09.2020. Исп. Магоян С.Х. т. 8(863)218-69-89 вход. № 514 25 «11» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №130/6^6
# №15-562-18573-2021
# №31О-127у.2О
# № 514
#
# Highlight Date
#  22.11.2021
#  01.09.2020
#  25 «11» 2021
#
# Highlight Org
# РОСТОВСКИЙ-НА-ДОНУ НАУЧНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ РАДИОСВЯЗИ»
# ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ УНИТАРНОЕ ПРЕДПРИЯТИЕ  ФЕДЕРАЛЬНЫЙ НАУЧНО-ПРОИЗВОДСТВЕННЫЙ ЦЕНТР  Российская Федерация
# АО «ЦМКБ «Алмаз»
# АО «ЗАСЛОН»
# ФГУП «РНИИРС»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Константин Геннадьевич
# К.Г. Голубеву
# В.А. Киселеву
# А.С. Митькина
# Магоян С.Х.
#
# -----------------------------------------------------
#
# letter_22_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# UI: Ш 1'bJUb I lUflLI' I U IUUU1 IH: UUlbJUO'JGkM Ud (JU I.  (Jll'l ГОСТ PB 15,703-2005 Форма I Не секретно   гриф при необходимости Экз. №  МИНИСТЕРСТВО ОБОРОНЫ  РОССИЙСКОЙ ФЕДЕРАЦИИ  ВОЙСКОВАЯ ЧАСТЬ  75385  г* Мончегорск  Мурманская обл., 184512  24 февраля 2021 г. №  На №  Начальнику отдела эксплуатации и ремонта НАЗ «Сокол» - филиал АО «РСКМиГ» Кузнецову Н.А> Факс: 8 (831) 242-32-70 Начальнику 256 BIT МО РФ Черникову А.С. Факс: 8 (831) 272-41-36 КОПИЯ Управляющему директору АО «Заслон» Адамене А.И.  Начальнику 286 ВИ МО РФ Масленникову В.Н. Факс; 8(812) 324-61-00 и УВЕДОМЛЕНИЕ № /НАС о вызове представителя поставщика  от « 24 »февраля 20 21 г. В дополнение к рекламационному акту' Ха 75385/4/222 от 13*10.2020 года адрес по факсу (мьзо) о-уо-ич.  Заместитель командира в/ч 75385 по ИАС_  должность, организация (предприятие)  ’  потребителя (получателя)   должность, организация (предприятие)  потребителя (получателя) подпись, инициалы, фамилия
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#   24 февраля 2021
#  « 24 »февраля 20
#  13*10.2020
#
# Highlight Org
# ОБОРОНЫ  РОССИЙСКОЙ ФЕДЕРАЦИИ  ВОЙСКОВАЯ ЧАСТЬ  75385  г
# НАЗ «Сокол»
# АО «РСКМиГ»
# АО «Заслон»
# УВЕДОМЛЕНИЕ № /НАС
#
# Highlight Person
# МИНИСТЕРСТВО
# Управляющему
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Кузнецову Н.А
# Черникову А.С
# Черникову А.С.
# Адамене А.И.
# Масленникову В.Н.
#
# -----------------------------------------------------
#
# letter_23_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# МИНИСТЕРСТВО ОБОРОНЫ  РОССИЙСКОЙ ФЕДЕРАЦИИ  (МИНОБОРОНЫ РОССИИ) г. Москва, 119160 августа 20 21 г. № 235/4/4/7jt<o На № 315-10379 от 25.08.2021 Г енеральному директору  управляющему организацией  АО «ЗАСЛОН»  А.А.ГОРБУНОВУ ул. Толи Комчака, д. 9, г. Санкт-Петербург, 196006 Уважаемый Александр Анатольевич! 23 «11» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 235/4/4/7jt<o
# № 315-10379
#
# Highlight Date
#  25.08.2021
#  23 «11» 2021
#
# Highlight Org
# ОБОРОНЫ  РОССИЙСКОЙ ФЕДЕРАЦИИ  (МИНОБОРОНЫ РОССИИ)
# АО «ЗАСЛОН»
#
# Highlight Person
# МИНИСТЕРСТВО
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Толи Комчака
# Александр Анатольевич
# А.А.ГОРБУНОВУ
#
# -----------------------------------------------------
#
# letter_24_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ТЕП:2723033 01 ФЕВ 2021 02:45РМ С. 1 ♦♦♦КРЭТ НПО РАДИОЭЛЕКТРОНИКА им. Й.И. ШИМКО Акционерное общество  «Научно-производственное объединение  «Радиоэлектроника» имени В.И. Шимко» На № 503-10359 от 21.12.2020 АО «НПО «Радиоэлектроника* им. В.И. Шимко» ИНН 16G0155764, КПП 168001001 420029, Россия, Республика Татарстан, г. Казани, ул. Журналистов, 50 теп^ (843) 272-65-60, факс; (943) 272-30-03, o-rr.all; lnfO@nposhlmko.ru, trttp^/stiimko.roBtccnn,nj Генеральному директору  управляющему организацией АО «ЗАСЛОН» А.А, Горбунову Начальнику 286 ВП МО РФ  В.Н, Масленикову 196006, г. Санкт-Петербург,  ул. Коли Томчака, д.9  факс: 8 (812) 324-61-00 Уважаемый Александр Анатольевич! Уважаемый Владимир Николаевич! Временный генеральный директор Начальник 714 ВП МО РФ Исп. Коротков Р.А. Тел. (843) 272-05-55 (доб. 653) “АтС. Белов В.Е. Гайдаенко Вход.М 514- ♦ 01» 02-2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 503-10359
#
# Highlight Date
#  21.12.2020
#  01» 02-2021
#
# Highlight Org
# НПО РАДИОЭЛЕКТРОНИКА им. Й.И. ШИМКО Акционерное общество  «Научно-производственное объединение  «Радиоэлектроника» имени В.И. Шимко
# АО «НПО «Радиоэлектроника* им. В.И. Шимко
# АО «ЗАСЛОН»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Горбунову Начальнику
# Коли Томчака
# Александр Анатольевич
# Владимир Николаевич
# Й.И. ШИМКО
# В.И. Шимко
# В.И. Шимко
# А.А, Горбунову
# В.Н, Масленикову
# Коротков Р.А.
# Белов В.Е.
#
# -----------------------------------------------------
#
# letter_25_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ  УНИТАРНОЕ ПРЕДПРИЯТИЕ  «ОРДЕНА ТРУДОВОГО КРАСНОГО ЗНАМЕНИ  РОССИЙСКИЙ НАУЧНО-ИССЛЕДОВАТЕЛЬСКИЙ  ИНСТИТУТ РАДИО ИМЕНИ М.П. КРИВОШЕЕВА» САНКТ-ПЕТЕРБУРГСКИЙ ФИЛИАЛ  «ЛЕНИНГРАДСКОЕ ОТДЕЛЕНИЕ НАУЧНО-  ИССЛЕДОВАТЕЛЬСКОГО ИНСТИТУТА РАДИО»  (Филиал ФГУП НИИР-ЛОНИИР) Б. Смоленский проси., 4, Санкт-Петербург, Россия, 192029  Телефон: (812) 600 64 10, факс: (812) 600 64 18 E-mail: orenloniir.ni hup://\\u w,loniir.ru  OKI IO 64266215, Ol PI I 1027700120766 И1 Ill/КПП 7709025230/7811430011 MM * W/&6 Ha №от  О финансовых документах Генеральному директору  управляющему организацией Горбунову А.А. Коли Томчака ул., д. 9,  Санкт-Петербург, 196006  т.ф. (812) 324-61-00 Уважаемый Александр Анатольевич ! Направляем в Ваш адрес счет на авансовый платеж согласно  пп. 3.1. договора от 11.11.2021 г. № 1620187304341412209022238/537/21-41  (НГК 1620187304341412209022238). Приложение: 1. Счёт № 161 от 23.11.2021 г. на 1 л. в 1 экз. 2. Уведомление об открытии счета на 1л. в 1 экз. Директор филиала  П.А. Михайлов Савичева Юлия Александровна  600-63-84 Вход. Ж 514-QS&L 25 ”11» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 1620187304341412209022238/537/21-41
# № 161
#
# Highlight Date
#  11.11.2021
#  23.11.2021
#  25 ”11» 2021
#
# Highlight Org
# ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ  УНИТАРНОЕ ПРЕДПРИЯТИЕ  «ОРДЕНА ТРУДОВОГО КРАСНОГО ЗНАМЕНИ  РОССИЙСКИЙ НАУЧНО-ИССЛЕДОВАТЕЛЬСКИЙ  ИНСТИТУТ РАДИО ИМЕНИ М.П. КРИВОШЕЕВА» САНКТ-ПЕТЕРБУРГСКИЙ ФИЛИАЛ  «ЛЕНИНГРАДСКОЕ ОТДЕЛЕНИЕ НАУЧНО-  ИССЛЕДОВАТЕЛЬСКОГО ИНСТИТУТА РАДИО»  (Филиал ФГУП НИИР-ЛОНИИР)
#
# Highlight Person
# Генеральному
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Б. Смоленский
# Александр Анатольевич
# Савичева
# Юлия Александровна
# ИМЕНИ М.П.
# Горбунову А.А.
# П.А. Михайлов
#
# -----------------------------------------------------
#
# letter_26_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# 111МИКРАН Акционерное общество «Научно-производственная фирма «Микран»  (АО «НПФ «Микран») пр-т Кирова, 51 д, г. Томск, Россия, 634041  +7 3822 90-00-29 | +7 3822 42-36-15 факс  mic@micran.ru | www.micran.ru 09.11.2021 № 11918/к На исх. №940-10819 от 18.10.2021 ОКПО 24627413, ОГРН 1087017011113  код по ОКОНХ 14760; 80400; 95300  ИНН/КПП 7017211757/701701001  Расчетный счет № 40702810900310000029  НОВОСИБИРСКИЙ ФИЛИАЛ АБ "РОССИЯ"  к/с 30101810950040000701 Генеральному конструктору  радиоэлектронного вооружения ВМФ  АО «ЗАСЛОН» Киселеву В.А. 196006, г. Санкт-Петербург,  ул. Коли Томчака, д. 9  Тел. (812) 327-90-99 Направляем в Ваш адрес коммерческое предложение на синтезаторы частот  ЕСС15К. Также сообщаем, что синтезаторы частот ЕСС15К обеспечивают свои характери­ стики при температуре воздействия минус 40 °C (холодный старт) и после температуры  воздействия минус 50 °C (температура хранения). Данные синтезаторы частот ЕСС15К поставляются только за приемкой ОТК. АО «НПФ «Микран» готово поставлять аналогичные синтезаторы с приемкой «5»  после проведения ОКР в соответствии с ГОСТ РВ 15.203. Приложение - Коммерческое предложение на 1л. С уважением, Зам. генерального директора по НИОКР А.А. Меньшиков Исполнитель: Огай К.Д. | +7 3822 90-00-29 доб. 1098 | kira@micran.ru Вход. №514- 10 .11.2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 11918/к
# №940-10819
# № 40702810900310000029
# №514-
#
# Highlight Date
#  09.11.2021
#  18.10.2021
#  10 .11.2021
#
# Highlight Org
# Акционерное общество «Научно-производственная фирма «Микран»
# АО «НПФ «Микран»
# НОВОСИБИРСКИЙ ФИЛИАЛ АБ "РОССИЯ"
# АО «ЗАСЛОН»
# АО «НПФ «Микран»
#
# Highlight Person
# МИКРАН
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# А.А. Меньшиков Исполнитель
# Огай К.Д.
# Киселеву В.А.
# НИОКР А.А.
#
# -----------------------------------------------------
#
# letter_26_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# МИКРАН АКЦИОНЕРНОЕ ОБЩЕСТВО НАУЧНО-ПРОИЗВОДСТВЕННАЯ ФИРМА 834041, г.Томск, пр-кт Кирова, 51Д, Тел: (3822) 41-34-03; 41-34-06. Факс: (3822)42-36-15. E-mail: mic@micran.ru. http://www.mlcran.ru Коммерческое предложение № МИК00002617 от 09.11.2021 АО "НПФ "Микран" Контактное лицо: Огай Кира Давидовна  Телефон: (3822) 90-00-29, доб. 1098  E-mail: klra@micran.ru Всего, руб Срок поставки  (дней) 864 000,00 864 000,00 Сумма  НДС 20 %  144 000,00 144 000,00  МИКРАН АО "ЗАСЛОН" Контактное лицо.Володягин А.В. Телефон: (812) 327-90-99, доб.2754  E-mail: Наименование Обозначение Артикул Кол-во Цена, руб. Сумма, руб Аксессуары СВЧ тракта 1 Синтезатор частот, 0,01...15 ГГц, тип 3,5мм (розетка) ЕСС15К ЖНКЮ.467872.017 Итого:  180 000,00 720 000,00 720 000,00  Условия поставки Предоплата Срок действия коммерческого предложения Сумма оборудования, указанного в коммерческом предложении составляет 864 000,00 (Восемьсот шестьдесят четыре тысячи рублей ноль копеек), в том числе НДС 20 % 144 000,00 (Сто сорок четыре тысячи рублей ноль копеек) Транспортные расходы за счет Поставщика  30 дней Зам.генерального директора по НИОКР  ДОЛЖНОСТЬ А.А. Меньшиков  расшифровка подписи
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № МИК00002617
#
# Highlight Date
#  09.11.2021
#
# Highlight Org
# МИКРАН АКЦИОНЕРНОЕ ОБЩЕСТВО НАУЧНО-ПРОИЗВОДСТВЕННАЯ ФИРМА 834041
# АО "НПФ "Микран"
# МИКРАН АО "ЗАСЛОН"
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Огай Кира Давидовна Телефон
# Володягин А.В.
# ДОЛЖНОСТЬ А.А.
#
# -----------------------------------------------------
#
# letter_27_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Нараулянсю раённы  выканаучы кампэт УПРАВЛЕНИЕ ПА ПРАЦЫ, ЗАНЯТАСЩ I САЦЫЯЛЬНАЙ АБАРОНЕ 247802, I. Пароу.зя вул. Камса.мольская, 19  пл. 21310, 21409, факс 22794 Бягучы рахунак 1Л 57АКВВ37300073702983300000  у ф-ле 317.ААБ Беларусбанк I. Мазыр БПК AKBBBY213I7 22.10.2021 г.№ На № от Наровлянский районный  и с и ол н ител ь н ы й ком итет УПРАВЛЕНИЕ ПО ТРУДУ, ЗАНЯТОСТИ И СОЦИАЛЬНОЙ ЗАЩИТЕ 247802 I. Наровля ул. Комсомольская, 19  тел.21310, 21409, факс 22794  Расчетный счеч BY57AKBB 37300073702983300000  в ф-ле 317 АСБ Беларусбанк  г. Мозырь БНК АКВВ1П 21317 ОАО «НТЦ «Завод «Ленинец»  ул. Томчака, 9 196084 г. Санкт-Петербург Российская Федерация Управление по труду, занятости и социальной защите  Наровлянского райисполкома Гомельской области Республики Беларусь  просит выслать справки о периоде работы, нахождении в отпуске по  уходу за ребенком 23.12.1986 г.р., о заработной плате, переименовании  и реорганизации организации на Стойка (Максименко) Людмилу  Григорьевну, 24.03.1964 г.р., работавшую в НПО «Ленинец» г.  Ленинграда в 1981-1987 годах фрезировщиком (цех 45, участок 5). Информация о работе получена со слов заявителя. Трудовая  книжки утрачена. Справка необходима для назначения пенсии по  возрасту. Информацию просим предоставить в кратчайшие сроки на наш  электронный адрес: narovlva.r-zs@mintrud.by и на бумажном носителе:  ул. Комсомольская, 19, г. Наровля, Гомельская область, Республик  Беларусь. Начальник управло^шя  Т.В.Двораковская ОЗПанарина 802355 41045 514-92ЙГ Вход. № 29 41» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № На
# № 29
#
# Highlight Date
# ...
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 518/10487
# № 2126187424921412208210473.
# № 6934
# № 6935
# №7842
# № 7843
# № 8061
# № 8062
# № 8472
# № 8947
# № 8948
#
# Highlight Date
#  06.07.2021
#  07.06.2021
#  30.09.2021
#  24.08.2021
#  24.08.2021
#  20.09.2021
#  20.09.2021
#  24.09.2021
#  24.09.2021
#  06.10.2021
#  20.10.2021
#  20.10.2021
#  23 -11» 2021
#
# Highlight Org
# АВИАКОМПАНИЯ «ПРОГРЕСС»
# ХОЛДИНГ ВЕРТОЛЕТЫ
# Акционерное общество  «Арсеньевская авиационная компания  «Прогресс» им. Н.П. Сазыкина»
# АО ААК «ПРОГРЕСС»
# Управляющей организации АО «Заслон»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Кузнецова Людмила Владимировна Телефон
# Н.П. Сазыкина
# Горбунову А.А.
# Масленникову В.Н.
#
# -----------------------------------------------------
#
# letter_1_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Ваш ответ просим в возможно кратчайший срок направить на эл. адрес  otd518@aacprogress.ru. Директор по МТС НачальникШ230 ВП МО РФ П.А. Медведев Е.А. Пахомов
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
# МТС НачальникШ
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# П.А. Медведев
# Е.А. Пахомов
#
# -----------------------------------------------------
#
# letter_10_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ПУВПИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО Исх.№1002- <270<Х «о <28, Ю. Акционерное общество «Светлана-Электронприбор» 194156, Санкт-Петербург, Энгельса пр., д. 27 Лит,С пом.2-Н  телефон/фйкс: (812) 554 0380 ИНН 7802070277, КПП 780201001, ОГТП 1027801543241, ОКПО 31946633 р/с 40702810380000001580 в Филиал ОПЕРУ Балк ВТБ (ПАО) в Санкт-Петербурге БИК 044030704, к/с 30101810200000000704 c-mail: mail@svetlana-cp.ru  АКЦИОНЕРНОЕ ОБЩЕСТВО  «ЗАСЛОН» 196006, Санкт-Петербург,  ул.Коли Томчака, д. 9 Генеральному директору управляющему  организацией А.А.Горбунову Начальнику 286 ВП МО РФ В.Н.Масленникову Копия: Заместителю генерального директора по ГОЗ  и сервисному обслуживанию  А.П.Бобрышеву Копия: Заместителю генерального директора ПАО  «Компания «Сухой» С.Н.Панасенко Уважаемые Александр Анатольевич и Владимир Николаевич! С Уважением, Заместитель директора АО «Светлана - Электронприбор» Начальник 127 ВП МО РФ Подготовил Киселев С.Н. (812) 554-03-66 Вход. $ 514-^3^ 28 «10» 2021г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №1002-
#
# Highlight Date
#  28 «10» 2021
#
# Highlight Org
# ПУВПИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО Исх
# Ю. Акционерное общество «Светлана-Электронприбор» 194156
# Филиал ОПЕРУ Балк ВТБ (ПАО)
# ОБЩЕСТВО  «ЗАСЛОН»
# ПАО  «Компания «Сухой»
# АО «Светлана - Электронприбор
#
# Highlight Person
# АКЦИОНЕРНОЕ
# А.А.Горбунову
# Подготовил
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Уважаемые Александр Анатольевич
# Владимир Николаевич
# А.А.Горбунову
# В.Н.Масленникову
# А.П.Бобрышеву
# С.Н.Панасенко
# Киселев С.Н.
#
# -----------------------------------------------------
#
# letter_11_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Kj ■  i Публичное f УI LJJIEDI sHTroe набережная Академика Туполева, д.17  Москва, а/я 20, 105005  тел.: (499) 263-75-00 факс: (499) 263-77-01, (499) 263-77-02 ОКПО 18982156 ОГРН 1027739263056  ИНН 7705313252/КПП 774550001 № Исх-24109-55 На № от 01.12.2021  п/в АБД объекта ВП-021МСМ Заместителю генерального  АО «Заслон»  директора Майкову А.С. mfo@onegroup.ru Начальник 286 ВП МО РФ Масленникову В.Н. Уважаемый Александр Сергеевич! Уважаемый Владимир Николаевич В ответ на Ваш исх.№ 210-11583 от 03.11.2021 направляю Вам  уточнённую схему 342МСМ-7200-413, с учётом внесения дополнительного  потока для регистрации на ИИС-32-АБДМ от выходной линии 16 УБС №2,  разъема Х7:34(а),35(б). Приложение: Схема 342МСМ-7200-413 - на 1 листе, направлено по эл. виде.  Пароль от архива получить у исполнителя. Заместитель директора дирекции программ  военной авиации по программам самолетов  А. А. Блажаюк Винничек Святослав Андреевич  (499) 263-77-77 доб. 19-77
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № Исх-24109-55
# № 210-11583
#
# Highlight Date
#  01.12.2021
#  03.11.2021
#
# Highlight Org
# Kj ■  i Публичное f УI LJJIEDI sHTroe набережная Академика Туполева
# АО «Заслон»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Александр Сергеевич
# Владимир Николаевич
# Винничек Святослав Андреевич
# Майкову А.С.
# Масленникову В.Н.
# А. А. Блажаюк
#
# -----------------------------------------------------
#
# letter_12_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Руководителю РОССТАТ УПРАВЛЕНИЕ ФЕДЕРАЛЬНОЙ СЛУЖБЫ  ГОСУДАРСТВЕННОЙ СТАТИСТИКИ  ПО Г.САНКТ-ПЕТЕРБУРГУ И ЛЕНИНГРАДСКОЙ ОБЛАСТИ  Проф. Попова ул., д. 39, г. Санкт-Петербург, 197376  Тел.: (812) 230-75-20, факс: (812) 234-06-36  http://petrostat.gks.ru; E-mail: petrostat@gks.ru (ПЕТРОСТАТ) На №от  О проведении выборочного обследования  организаций о заработной плате работников  по профессиям и должностям за октябрь 2021 года В соответствии с Федеральным планом статистических работ на 2021 год,  утвержденным распоряжением Правительства РФ от 06.05.08 № 671-р (с измене­ ниями), проводится выборочное обследование но форме № 57-Т «Сведения о зара­ ботной плате работников по профессиям и должностям за октябрь 2021 года», ут­ вержденной приказом Росстата от 30.07.2021 № 457. Обследованию подлежат юридические лица (без субъектов малого  предпринимательства) и их обособленные подразделения всех форм  собственности. Согласно сформированной выборочной совокупности Ваша организация  (обособленное подразделение) вошла в число респондентов, подлежащих обследо­ ванию. Перечень подлежащих обследованию организаций по форме № 57-Т разме­ щен на портале Росстата: http://websbor.gks.ru/ Бланк формы № 57-Т, ХМТ-шаблон и электронная версия приказа Росстата  об утверждении формы размещены на официальном сайте Петростата по адресу:  https://petrostat.gks.ru/ Респондентам/ Формы федерального статистического на­ блюдения и формы бухгалтерской (финансовой) отчетности/ Альбом форм феде­ рального статистического наблюдения/ Рынок труда. Перед заполнением отчета необходимо внимательно ознакомиться с Указа­ ниями по его заполнению, размещенными на бланке формы. Форма № 57-Т состоит из двух разделов. В обязательном порядке должны  быть заполнены оба раздела отчета. Раздел I заполняется на всех работников орга­ низации (обособленного подразделения). Численность работников, подлежащих  индивидуальному обследованию в разделе II формы, зависит от числа работников,  полностью отработавших октябрь, и составляет от 8 до 64 человек.  „Вх. № 514-9107  от 22.11.2021
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 671-р
# № 57-Т
# № 457.
# № 57-Т
# № 57-Т
# № 57-Т
# № 514-9107
#
# Highlight Date
#  06.05.08
#  30.07.2021
#  22.11.2021
#
# Highlight Org
# Руководителю РОССТАТ УПРАВЛЕНИЕ ФЕДЕРАЛЬНОЙ СЛУЖБЫ  ГОСУДАРСТВЕННОЙ СТАТИСТИКИ  ПО Г.САНКТ-ПЕТЕРБУРГУ И ЛЕНИНГРАДСКОЙ ОБЛАСТИ  Проф. Попова ул
#
# Highlight Person
# Правительства
# Росстата
# Росстата
# Росстата
# Петростата
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Указа­
#
# -----------------------------------------------------
#
# letter_12_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Организациями. в которых численность работников полностью  отработавших октябрь, составляет 1000 человек и более заполняется еще вкладыш,  на котором сведения о работниках проставляются с порядковыми номерами от 33  до 64. В целях помощи по заполнению формы № 57-Т в Интернете  на официальном сайте Петростата размещено Пособие для кодирования профессий  рабочих и должностей служащих в выборочном обследовании организаций о зара­ ботной плате работников за октябрь 2021 г., составленное на основе (ЖИД ГР по  адресу: https://petrostat.gks.ru/ Респондентам/ Формы федерального статистического  наблюдения и формы бухгалтерской (финансовой) отчетности/ Альбом форм феде­ рального статистического наблюдения/ Рынок груда / Форма № 57-Т. В соответствии с Федеральным законом от 31.12.2020 г. № 500 ФЗ «О  внесении изменений в Федеральный закон «Об официальном статистическом учете  и системе государственной статистики в Российской Федерации» (от 29.11.2007  года №282-ФЗ) с 30 декабря 2020 года все юридические лица и граждане,  осуществляющие предпринимательскую деятельность без образования  юридического лица (индивидуальные предприниматели), обязаны представлять  первичные статистические данные но формам федерального статистического  наблюдения исключительно в форме электронного документа, подписанного  электронной подписью. При этом организация может представить Форму № 57-Т в электронном виде  следующими способами: - через специализированных операторов связи; через систему Web-сбора в режиме on-line или off-line (подробности на  сайте Петростата по адресу: https://petrostat.gks.ru/ Респондентам/ Статистическая  отчетность в электронном виде/ Система Web-сбора); Срок предоставления формы не позднее 30 ноября 2021 года. Акцентируем Ваше внимание, что нарушение порядка представления стати­ стической информации или представление недостоверной информации влечет от­ ветственность, установленную статьей 13.19 Кодекса РФ об административных  правонарушениях от 30.12.2001 № 195-ФЗ (с изменениями и дополнениями от 30  декабря 2015 № 442-ФЗ). Заместитель руководителя С.В. Черных Зыкова Елена Александровна,  (812) 230-35-40 Кунтышева Людмила Игоревна. (812) 234-07-42 Отдел социальной статистики
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# № 57-Т
# № 57-Т.
# № 500
# №282-ФЗ)
# № 57-Т
# № 195-ФЗ
# № 442-ФЗ).
#
# Highlight Date
#  31.12.2020
#  29.11.2007
#  30 декабря 2020
#  30 ноября 2021
#  30.12.2001
#  30  декабря 2015
#
# Highlight Org
# Форму № 57-Т
# С.В. Черных Зыкова
# Отдел социальной статистики
#
# Highlight Person
# Интернете
# Петростата
# Петростата
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Елена Александровна
# Людмила Игоревна
# С.В. Черных
#
# -----------------------------------------------------
#
# letter_13_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ЧКЦИОНЕРНОЕ ОБЩЕСТВО «СЕВЕРО-Г\П \ДНЫЙ РЕГИОНАЛЬНЫЙ ЦЕНТР  КОНЦЕРН А ВКО « V IMA 1 - АНТЕЙ» - ОБУХОВСКИЙ ЗАВОД» ic.1 факс: < Ml » 5hJ-9S • I i c-ni:iil. Фчн: go/.ru 1‘>2<|Ц. Рис», ня. < .‘.iiiki I к'••.‘J'1 Л Hp.’Viicsi I >6у'.,чк|.-,.ч| <ь5чри;1| •. 1?н. 1е.<сф-Ш i-'lli  1 2.11.2021 s  На №60-10133 от 20.09.2021г.  О"? I IM I’H Н>ГК2'Ч'.Ч7<', lllill Kllil "Si I I4J64K 7‘Н|1^П1и] < H>;icli.is-.Xv < >b,Hum pi., 11" >I-t’cn-r-.bP.ii'-.U. 111 J"I 2. id iS k’i kd-’^.-Vl, ;d I.o, <SI ll ЗМ-Чч.|!. e ni.BJ .Iouj t'-'/.ni Управляющему директору АО «Заслон» Адаменя А.И. 196006, г. Санкт-Петербург,  ул. Коли Томчака, д.9  Тел.:(812)327-90-99  Факс:(812)324-61-00  e-mail: info@onegroup.ru На Ваш исх. №60-10133 от 20.09.2021г. сообщаю, что на АО «Обуховский  завод» отсутствует техническая возможность выполнения данного запроса. С уважением, Первый заместитель  генерального директора-  технический директор В.В. Шафранский Исп. Шубина Мария Борисовна  тел. (812) 363-92-96 Г\!= 1 п
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №60-10133
# №60-10133
#
# Highlight Date
#  2.11.2021
#  20.09.2021
#  20.09.2021
#
# Highlight Org
# ЧКЦИОНЕРНОЕ ОБЩЕСТВО «СЕВЕРО-Г\П \ДНЫЙ РЕГИОНАЛЬНЫЙ ЦЕНТР  КОНЦЕРН А
# ОБУХОВСКИЙ ЗАВОД»
# АО «Заслон»
# АО «Обуховский  завод
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Шубина
# Мария Борисовна
# Адаменя А.И.
# В.В. Шафранский
#
# -----------------------------------------------------
#
# letter_14_0
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# АКЦИОНЕРНОЕ ОБЩЕСТВО ЛЕТНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ  • GROMOV FLIGHT RESEARCH INSTITUTE о ГОСУДАРСТВЕННЫЙ НАУЧНЫЙ ЦЕНТР РОССИЙСКОЙ ФЕДЕРАЦИИ имени М.М. ГРОМОВА Управляющему директору  АО «ЗАСЛОН»    Адамене А.И.  РФ, 196006, г. Санкт-Петербург, ул. Коли Томчака, д.9, лит. Н, о/я 167 ГРУППА КОМПАНИЙ ОАК На №от Об исполнении обязательств Уважаемый Анатолий Иванович! Направляю Вам для подписания два экземпляра акта приема-передачи (возврата)  по Договору аренды от 24 декабря 2020 г. №7049197013а (часть нежилого помещения Приложение: по тексту на 2-х листах. Генеральный директор Е.Ю. Пушкарский 056460 ППППППППШППШПШ РОССИЙСКАЯ ФЕДЕРАЦИЯ 140180, О МОСКОВСКАЯ ОБЛАСТЬ, г.ЖУКОВСКИЙ. ул. ГАРНАЕВА, д. 2А ШПШШПШШШПНШ  Our address: Russian Federation о 140180, Gamacv str, bld.2A, Zhukovsky, Moscow Region  О ТЕЛЕФОН ДЛЯ СПРАВОК: (495) 556-59-38 О ФАКС: (495) 556-70-70 о Contact telephons: (495) 556-59-38, Fax: (495) 556-70-70 e-mail: secretarv.chief@lii.ru Исполнитель: Дронова Наталья Вячеславовна Телефон: 8 (495) 556-53-53
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
# №7049197013а
#
# Highlight Date
#  24 декабря 2020
#
# Highlight Org
# АКЦИОНЕРНОЕ ОБЩЕСТВО ЛЕТНО-ИССЛЕДОВАТЕЛЬСКИЙ ИНСТИТУТ  • GROMOV FLIGHT RESEARCH INSTITUTE о ГОСУДАРСТВЕННЫЙ НАУЧНЫЙ ЦЕНТР РОССИЙСКОЙ ФЕДЕРАЦИИ имени М.М. ГРОМОВА
# АО «ЗАСЛОН»
# ГРУППА КОМПАНИЙ ОАК
# ППППППППШППШПШ РОССИЙСКАЯ ФЕДЕРАЦИЯ
#
# Highlight Person
# Управляющему
# Zhukovsky
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# Коли Томчака
# Анатолий Иванович
# Дронова
# Наталья Вячеславовна Телефон
# М.М. ГРОМОВА
# Адамене А.И.
# Е.Ю. Пушкарский
#
# -----------------------------------------------------
#
# letter_14_1
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# приема-передачи  (возврата Объекта аренды) г. Жуковский 2021 г. Стороны установили (не установили) следующие недостатки:  Арендодатель: Генеральный директор АО «ЛИИ им. М.М. Громова» Арендатор: Управляющий директор АО «ЗАСЛОН» (Е.Ю. Пушкарский) 2021 г. 2021 г.
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# Highlight Number
#
# Highlight Date
#
# Highlight Org
# Объекта аренды
# АО «ЛИИ им. М.М. Громова
# АО «ЗАСЛОН»
#
# Highlight Person
#
# Persons regex XXXX X.X. | X.X. XXXX:
#
# Highlight Person
# М.М. Громова
# Е.Ю. Пушкарский
#
# -----------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bp/g99cvr5n1zn7htqvwvvr8tw40000gn/T/ipykernel_26784/1632453161.py in <module>
#      30
#      31     for doc_name in get_files(PDF_PATH, ".pdf"):
# ---> 32       images = convert_from_path(PDF_PATH + doc_name, dpi = STANDART_DPI * DPI_SCALE)
#      33
#      34       fp = open(PDF_PATH + doc_name, 'rb')
#
# ~/miniconda3/envs/letter/lib/python3.8/site-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     206     for uid, proc in processes:
#     207         try:
# --> 208             data, err = proc.communicate(timeout=timeout)
#     209         except TimeoutExpired:
#     210             proc.kill()
#
# ~/miniconda3/envs/letter/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1026
#    1027             try:
# -> 1028                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1029             except KeyboardInterrupt:
#    1030                 # https://bugs.python.org/issue25942
#
# ~/miniconda3/envs/letter/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1866                             'failed to raise TimeoutExpired.')
#    1867
# -> 1868                     ready = selector.select(timeout)
#    1869                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1870
#
# ~/miniconda3/envs/letter/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
